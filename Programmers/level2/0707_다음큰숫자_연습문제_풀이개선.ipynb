# %%
def solution(n):
    answer = 0
    i = 0
    
    binary = bin(n)

    cnt = binary.count('1')
#     if not '0' in binary:
#         answer = int(binary[0]+'0'+binary[1:] , 2)
#     else:
    while True:
        i += 1
        if cnt == bin(i+n).count('1'):
            return int(i+n)
            
    return answer
solution(15)
# Out:
# 23

# %%
def solution(n):
    cnt = bin(n).count('1')
    for i in range(n+1, 2*n+1):
        if bin(i).count('1') == cnt:
            return i
solution(1)
# Out:
# 2
