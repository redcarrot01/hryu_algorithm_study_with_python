# %%
def solution(s):
    answer = []
    binary_cnt ,zero_cnt = 0,0
    while s !='1':
        zero_cnt += s.count('0')
        length = len(s)-s.count('0')
        s = bin(length)[2:]
        binary_cnt+= 1
    return [binary_cnt, zero_cnt]

solution("110010101001")
# Out:
# [3, 8]
