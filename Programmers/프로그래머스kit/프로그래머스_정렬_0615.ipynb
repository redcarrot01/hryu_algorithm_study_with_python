# %% [markdown]
# ## k번째 수

# %%
def solution(array, commands):
    answer = []
    for command in commands:
        new_array = array[command[0]-1 : command[1]]
        new_array.sort()
        answer.append(new_array[command[2]-1])
    return answer

# %% [markdown]
# ## 가장 큰 수

# %%
def solutions(numbers):
    numbers = list(map(str, numbers))
    numbers.sort(key = lambda x : x*4[L4], reverse=True)
    answer = ''.join(numbers) if numbers[0] != '0' else '0'

# %% [markdown]
# ## h-index

# %%
# 0<=h<=n이라는 것이 중요
def solution(citations):
    citations.sort(reverse=True)
    length = len(citations)
    cnt=0
    for i in range(length):
        if i+1 <= citations[i]:
            cnt += 1
    return cnt
solution([3, 0, 6, 1, 5])
solution([4,5])
solution([100,100,100,5])
solution([6,6,6,6,6,7])
# Out:
# 6
