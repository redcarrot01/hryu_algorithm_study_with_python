# %%
def solution(s):
    if s.isdigit():
        if 4==len(s) or len(s)==6:
            return True
        return False
    return False
solution("a234") 
solution("1234")
# Out:
# True

# %%
def solution(s):
    return s.isdigit() and len(s) in (4,6)
solution("a234")
# Out:
# False
