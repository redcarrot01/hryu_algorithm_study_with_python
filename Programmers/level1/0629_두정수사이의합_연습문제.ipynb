# %%
def solution(a, b):
    answer = 0
    if a>=b:
        for i in range(b, a+1):
            answer += i
    else:
        for j in range(a, b+1):
            answer += j
    return answer
solution(3,5)
# Out:
# 12

# %%
#  다른 풀이
def adder(a, b):
    if a> b: 
        a,b= b,a
    return sum(range(a, b+1))
solution(3,5)
# Out:
# 12

# %%
# (가장작은숫자+가장큰숫자)*숫자개수 /2
def solution(a, b):
    
    return (a+b)*(abs(b-a)+1)//2
solution(3,5)
# Out:
# 12
