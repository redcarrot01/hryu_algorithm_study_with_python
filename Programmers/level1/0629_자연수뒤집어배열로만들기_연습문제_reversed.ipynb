# %%
def solution(n):
    n = list(str(n))
    n.reverse()
    return list(map(int, n))
solution(12345)
# Out:
# ['5', '4', '3', '2', '1']
# [5, 4, 3, 2, 1]

# %%
# reverse는 리스트에서 제공하고 순서 뒤집음, 리턴x, 
#reversed는 내장함수, 인덱스로 접근하므로 딕셔너리 지원x, 리스트를 리턴
def digit_reverse(n):
    #print(reversed(str(n))) ['5', '4', '3', '2', '1']
    return list(map(int, reversed(str(n))))

solution(12345)
# Out:
# ['5', '4', '3', '2', '1']
# [5, 4, 3, 2, 1]
