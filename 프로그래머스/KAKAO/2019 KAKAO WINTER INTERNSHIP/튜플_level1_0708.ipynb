# %%
def solution(s):
    answer = []
    
    return answer

# %%
a = "{{4,2,3},{3},{2,3,4,1},{2,3}}"
# b=a.split(",")
a = a.replace("{", " ")
a = a.replace("}"," ")
print(a)
# a = a.repalce(",", "")
b = a.split(' , ')
b 
# arr = a.split(" ")
# print(arr)
# for i in arr:
#     if i.isdigit():
#         print(i)
# Out:
#   4,2,3 , 3 , 2,3,4,1 , 2,3
# ['  4,2,3', '3', '2,3,4,1', '2,3  ']
