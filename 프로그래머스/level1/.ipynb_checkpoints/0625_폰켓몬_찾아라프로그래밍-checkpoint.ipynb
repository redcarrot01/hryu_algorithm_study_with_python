# %%
def solution(nums):
    answer = len(set(nums))
    if answer > len(nums)//2:
        return len(nums)//2
    return answer
solution([3,1,2,3])
#solution([3,3,3,2,2,4])
# Out:
# 2

# %%
# 다른 사람 풀이
def solution(nums):
    return min(len(nums)//2, len(set(nums)))
solution([3,1,2,3])
# Out:
# 2
