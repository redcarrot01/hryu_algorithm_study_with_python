# %%
def solution(seoul):
    for i in range(len(seoul)):
        if seoul[i] == "Kim":
            return "김서방은 "+str(i)+"에 있다"
solution(["Jane", "Kim"])
# Out:
# '김서방은 1에 있다'

# %%
def solution(seoul):
    return "김서방은 {}에 있다".format(seoul.index('Kim'))
solution(["Jane", "Kim"])
# Out:
# '김서방은 1에 있다'
