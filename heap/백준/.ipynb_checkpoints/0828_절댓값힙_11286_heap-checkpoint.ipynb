# %%
#import sys
#input = sys.stdin.readline
import heapq
heap = []
heap1 = []
n = int(input())
for i in range(n):
    x = int(input())
    if x == 0:
        if not heap :
            print(0)
        else:
            print(heapq.heappop(heap)[1])
    else:
        heapq.heappush(heap, (abs(x), x))
# Out:
# 18
# 1
# -1
# 0
# -1
# 0
# 1
# 0
# 0
# 1
# 1
# -1
# -1
# 2
# -2
# 0
# -1
# 0
# -1
# 0
# 1
# 0
# 1
# 0
# -2
# 0
# 2
# 0
# 0
