# %%
#import sys
#input = sys.stdin.readline
import heapq
heap = []
n = int(input())
for i in range(n):
    x = int(input())
    if x == 0:
        if not heap:
            print(0)
        else:
            y = heapq.heappop(heap)
            print(y)
    else:
        heapq.heappush(heap, x)
# Out:
# 9
# 0
# 0
# 1234
# 1
# 2
# 0
# 1
# 0
# 2
# 0
# 1234
# 0
# 0
# 32
