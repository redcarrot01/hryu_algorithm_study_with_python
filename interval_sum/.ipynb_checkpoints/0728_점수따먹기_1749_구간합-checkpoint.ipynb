# %%
# 대실패 
    def dfs(x, y, temp):
    dx = [-1, 1, 0 ,0]
    dy = [0, 0, -1, 1]
    for i in range(4):
        nx = x + dx[i]
        ny = y + dy[i]
        
        if visited[nx][ny] == 0 and nx >=0 and nx<n and ny>=0 and ny<m :
            visited[nx][ny] =1
            if temp <= temp+graph[nx][ny]:
                temp += graph[nx][ny]
                dfs(nx, ny, temp)
                return temp
            else:
                break
            #visited[nx][ny] =1
            
                

n,m = map(int, input().split())
graph = [list(map(int, input().split())) for _ in range(n)]
visited = [[0]*m for _ in range(n)]

result = int(-1e9)
for i in range(n):
    for j in range(m):
        if visited[i][j] == 0:
            visited[i][j] =1
            temp = dfs(i, j, graph[i][j])
            #temp = max(temp, temp+graph[0][0])
            result= max(result, temp)
            temp = 0
print(result)
# Out:
#   File "<ipython-input-20-ca0f10fb9ccf>", line 2
#     def dfs(x, y, temp):
#     ^
# IndentationError: unexpected indent

# %%
n,m = map(int, input().split())
graph =[[0]*(m+1)] + [[] for _ in range(n)]
#graph = [list(map(int, input().split())) for _ in range(n)]
for i in range(1, n+1):
    graph[i] = [0]+list(map(int,input().split()))
#print(graph)
answer = -10001
for i in range(1, n+1):
    for j in range(1, m+1):
        graph[i][j] = graph[i][j] + graph[i][j-1] + graph[i-1][j] - graph[i-1][j-1];
print(graph)
for i in range(1, n+1):
    for j in range(1, m+1):
        for k in range(i, n+1):
            for l in range(j, m+1):
                result = graph[k][l] - graph[i-1][l] - graph[k][j-1] + graph[i-1][j-1]
                print(result)
                if answer < result:
                    answer = result
                    
print(answer)
# Out:
# 3 5
# 2 3 -21 -22 -23
# 5 6 -22 -23 -25
# -22 -23 4 10 2
# [[0, 0, 0, 0, 0, 0], [0, 2, 5, -16, -38, -61], [0, 7, 16, -27, -72, -120], [0, -15, -29, -68, -103, -149]]
# 2
# 5
# -16
# -38
# -61
# 7
# 16
# -27
# -72
# -120
# -15
# -29
# -68
# -103
# -149
# 3
# -18
# -40
# -63
# 9
# -34
# -79
# -127
# -14
# -53
# -88
# -134
# -21
# -43
# -66
# -43
# -88
# -136
# -39
# -74
# -120
# -22
# -45
# -45
# -93
# -35
# -81
# -23
# -48
# -46
# 5
# 11
# -11
# -34
# -59
# -17
# -34
# -52
# -65
# -88
# 6
# -16
# -39
# -64
# -17
# -35
# -48
# -71
# -22
# -45
# -70
# -18
# -31
# -54
# -23
# -48
# -13
# -36
# -25
# -23
# -22
# -45
# -41
# -31
# -29
# -23
# -19
# -9
# -7
# 4
# 14
# 16
# 10
# 12
# 2
# 16
