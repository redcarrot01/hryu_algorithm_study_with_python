# %% [markdown]
# https://suhak.tistory.com/77
#
# 카탈란 수 알고리즘을 이용한다
# 카탈란 수 : 쌍을 이루는 것들을 나열하는 모든 경우의 수
# 카탈란 수열 문제들 : 모든 괄호 짝, 산 만들기, 대각선 피해가기, 다각형을 삼각형으로 나누기
#
# 모든 괄호 짝
# n쌍의 괄호가 잘 짜놓은 방법을 Cn
# (A)B : A에 괄호가 K쌍 있다면, B에는 N-1-K쌍이 존재
# C1 = C0C0
# C2 = C0C1 + C1C0
# C3 = C0C2 + C1C1 + C2C0
# C3: 3쌍의 괄호가 있다. 이미 1쌍의 괄호가 있다고 가정,
# 이 괄호를 기준으로 괄호안에 넣을 수 있는 경우 * 괄호 밖 경우
# 1. 안에 2개 * 밖에 0개 C2*C0
# 2. 안에 1개 * 밖에 1개 C1*C1
# 3. 안에 0개 * 밖에 2개 C0*C2
#
# > Cn =  Σ Ci*Cn-1-i (i는 0~n-1)
#
# 카탈란 수 공식 : Catalan(n) = (2n)! / (n! * (n+1)!)
#
# 한가지 경우를 시행하면, 그와 쌍이 되는 다른 경우를 반드시 시행해야 하는 모든 개수
# 괄호쌍의 경우 ( 나오면 ) 반드시 나옴
# ( 2번 -> ) 2번 나옴

# %%
import math 
def catalan(n): 
    return math.factorial(2*n) // (math.factorial(n) * math.factorial(n+1))
t = int(input())
for _ in range(t):
    l = int(input())
    if l % 2 ==1:
        print(0)
    else:
        print(catalan(l//2)% 1000000007)
# Out:
# 3
# 1
# 0
# 2
# 1
# 4
# 2
